# %% [markdown]
# <a href="https://colab.research.google.com/github/papporica123/capstrone-project-1/blob/main/DSCM11L4A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-350d98c9-8d3f-495a-9f56-30f09ab7081b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-350d98c9-8d3f-495a-9f56-30f09ab7081b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving database.sqlite to database.sqlite

# %%
# Connect with sqlite database
# Import necessary libraries
import pandas as pd
import numpy as np

import sqlite3

database = 'database.sqlite'

conn = sqlite3.connect(database)
print('Opened data successfully')
# Out:
# Opened data successfully

# %%
# Display all the tables of the database
df = pd.read_sql("""SELECT *
                    FROM sqlite_master
                    WHERE type='table';""", conn)
df
# Out:
#      type  ...                                                sql
# 0   table  ...  CREATE TABLE [Player] (\n\t[Player_Id]\tintege...
# 1   table  ...  CREATE TABLE [Extra_Runs] (\n\t[Match_Id]\tint...
# 2   table  ...  CREATE TABLE [Batsman_Scored] (\n\t[Match_Id]\...
# 3   table  ...  CREATE TABLE [Batting_Style] (\n\t[Batting_Id]...
# 4   table  ...  CREATE TABLE [Bowling_Style] (\n\t[Bowling_Id]...
# 5   table  ...  CREATE TABLE [Country] (\n\t[Country_Id]\tinte...
# 6   table  ...  CREATE TABLE [Season] (\n\t[Season_Id]\tintege...
# 7   table  ...  CREATE TABLE [City] (\n\t[City_Id]\tinteger NO...
# 8   table  ...  CREATE TABLE [Outcome] (\n\t[Outcome_Id]\tinte...
# 9   table  ...  CREATE TABLE [Win_By] (\n\t[Win_Id]\tinteger N...
# 10  table  ...  CREATE TABLE [Wicket_Taken] (\n\t[Match_Id]\ti...
# 11  table  ...  CREATE TABLE [Venue] (\n\t[Venue_Id]\tinteger ...
# 12  table  ...  CREATE TABLE [Extra_Type] (\n\t[Extra_Id]\tint...
# 13  table  ...  CREATE TABLE [Out_Type] (\n\t[Out_Id]\tinteger...
# 14  table  ...  CREATE TABLE [Toss_Decision] (\n\t[Toss_Id]\ti...
# 15  table  ...  CREATE TABLE [Umpire] (\n\t[Umpire_Id]\tintege...
# 16  table  ...  CREATE TABLE [Team] (\n\t[Team_Id]\tinteger NO...
# 17  table  ...  CREATE TABLE [Ball_by_Ball] (\n\t[Match_Id]\ti...
# 18  table  ...  CREATE TABLE [sysdiagrams] (\n\t[name]\tnvarch...
# 19  table  ...             CREATE TABLE sqlite_sequence(name,seq)
# 20  table  ...  CREATE TABLE [Match] (\n\t[Match_Id]\tinteger ...
# 21  table  ...  CREATE TABLE [Rolee] (\n\t[Role_Id]\tinteger N...
# 22  table  ...  CREATE TABLE [Player_Match] (\n\t[Match_Id]\ti...
#
# [23 rows x 5 columns]

# %%
# Display the first five rows of the Player_Match table
player_match = pd.read_sql("""SELECT *
                        FROM Player_Match""", conn)

player_match.head()
# Out:
#    Match_Id  Player_Id  Role_Id  Team_Id
# 0    335987          1        1        1
# 1    335987          2        3        1
# 2    335987          3        3        1
# 3    335987          4        3        1
# 4    335987          5        3        1

# %%
# Check the presence of null values in the Player_Match table
null_player_match = pd.read_sql("""SELECT *
                        FROM Player_Match
                        WHERE Team_Id IS NULL""", conn)

null_player_match
# Out:
# Empty DataFrame
# Columns: [Match_Id, Player_Id, Role_Id, Team_Id]
# Index: []

# %%
# Display the first five rows of the Match table
toss_dec = pd.read_sql("""SELECT *
                        FROM Match""", conn)

toss_dec.head()
# Out:
#    Match_Id  Team_1  Team_2  ... Outcome_type  Match_Winner  Man_of_the_Match
# 0    335987       2       1  ...            1           1.0               2.0
# 1    335988       4       3  ...            1           3.0              19.0
# 2    335989       6       5  ...            1           6.0              90.0
# 3    335990       7       2  ...            1           2.0              11.0
# 4    335991       1       8  ...            1           1.0               4.0
#
# [5 rows x 13 columns]

# %%
# Check the presence of null values in the Match table
null_match = pd.read_sql("""SELECT *
                        FROM Match
                        WHERE MATCH_Winner IS NULL""", conn)

null_match
# Out:
#    Match_Id  Team_1  Team_2  ... Outcome_type  Match_Winner  Man_of_the_Match
# 0    501270       6      10  ...            2          None              None
# 1    829768       2       5  ...            2          None              None
# 2    829818       2       6  ...            2          None              None
#
# [3 rows x 13 columns]
